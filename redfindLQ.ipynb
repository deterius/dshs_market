# %%
import requests
import pandas as pd
from datetime import datetime


url = "https://unofficial-redfin.p.rapidapi.com/properties/list"

querystring = {
    "region_id": "10297",
    "region_type": "6",
    "uipt": "1,2,3,4,7,8",
    "status": "9",
    "sf": "1,2,3,5,6,7",
    "num_homes": "500"
}

headers = {
    "X-RapidAPI-Key": "b60faef7a6msh2c985c19232815ap1c4e46jsna04a608045c9",
    "X-RapidAPI-Host": "unofficial-redfin.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# Extracting nested data from 'homes' -> 'homeData'
homes_data = [home['homeData'] for home in data['homes']]


# Convert the extracted data to pandas DataFrame
df = pd.json_normalize(homes_data)

# Get the current date and time
current_datetime = datetime.now()

# Add the current date and time as a new column in the DataFrame
df['Data Requested Date'] = current_datetime

# %%
import re

# Function to format column names
def format_column_name(column_name):
    # Replace periods with spaces
    column_name = column_name.replace('.', ' ')

    # Add space before capital letters and make lowercase
    formatted_name = ''.join([' ' + char if char.isupper() else char for char in column_name]).strip().lower()
    
    # Remove leading/trailing spaces and replace multiple spaces with a single space
    formatted_name = re.sub(' +', ' ', formatted_name.strip()).lower()

    return formatted_name
# Format the column headers
df.columns = [format_column_name(col) for col in df.columns]

# %%
# Convert 'days on market days on market value' to numeric
df['days on market days on market value'] = pd.to_numeric(df['days on market days on market value'], errors='coerce')
# Convert 'days on market days on market value' to a timedelta and subtract from 'data requested date'
df['date added to market'] = df['data requested date'] - pd.to_timedelta(df['days on market days on market value'], unit='D')

# %%
df['days on market time on redfin seconds'] = pd.to_numeric(df['days on market time on redfin seconds'], errors='coerce')
# Convert 'days on market time on redfin seconds' to a timedelta and subtract from 'data requested date'
df['date added to redfin'] = df['data requested date'] - pd.to_timedelta(df['days on market time on redfin seconds'], unit='s')

# %%
# Convert 'last sale data last sold date seconds' to numeric, filling NaNs with 0
df['last sale data last sold date seconds'] = pd.to_numeric(df['last sale data last sold date seconds'], errors='coerce').fillna(0)

# Apply the calculation to all rows
df['date of last sale'] = df['data requested date'] - pd.to_timedelta(df['last sale data last sold date seconds'], unit='s')

# For rows where 'last sale data last sold date seconds' is 0, set 'date of last sale' to NaN or some default value
df.loc[df['last sale data last sold date seconds'] == 0, 'date of last sale'] = pd.NaT  # or some other default value

# %%
df.to_excel('data/dshs_test_lq.xlsx')

# %%
df.describe()
# Out:
#        beds value  baths value  days on market days on market value  \
# count  396.000000   396.000000                           395.000000
# mean     3.467172     3.311869                            61.081013
# std      4.270764     4.087488                            56.346810
# min      1.000000     1.000000                             1.000000
# 25%      3.000000     2.000000                            23.000000
# 50%      3.000000     3.000000                            47.000000
# 75%      4.000000     3.500000                            75.500000
# max     86.000000    80.000000                           414.000000
#
#        days on market time on redfin seconds  \
# count                           3.950000e+02
# mean                            5.274481e+06
# std                             4.870745e+06
# min                             7.459000e+04
# 25%                             2.006488e+06
# 50%                             4.058540e+06
# 75%                             6.522057e+06
# max                             3.576916e+07
#
#        days on market time on redfin nanos  \
# count                         3.930000e+02
# mean                          4.929466e+08
# std                           2.883362e+08
# min                           1.000000e+06
# 25%                           2.550000e+08
# 50%                           4.910000e+08
# 75%                           7.180000e+08
# max                           9.920000e+08
#
#        days on market listing added date nanos  year built year built value  \
# count                             3.950000e+02                   377.000000
# mean                              5.156734e+08                  2002.315650
# std                               2.862441e+08                    14.316283
# min                               3.000000e+06                  1937.000000
# 25%                               2.570000e+08                  1990.000000
# 50%                               5.260000e+08                  2003.000000
# 75%                               7.660000e+08                  2013.000000
# max                               9.970000e+08                  2024.000000
#
#        last sale data last sold date seconds  direct access info time zone id  \
# count                           3.990000e+02                            399.0
# mean                            1.009651e+09                              7.0
# std                             7.123629e+08                              0.0
# min                             0.000000e+00                              7.0
# 25%                             0.000000e+00                              7.0
# 50%                             1.409209e+09                              7.0
# 75%                             1.612210e+09                              7.0
# max                             1.696316e+09                              7.0
#
#        full baths value  ...  bath info computed full baths  \
# count        396.000000  ...                     396.000000
# mean           3.106061  ...                       3.106061
# std            4.045171  ...                       4.045171
# min            1.000000  ...                       1.000000
# 25%            2.000000  ...                       2.000000
# 50%            3.000000  ...                       3.000000
# 75%            3.000000  ...                       3.000000
# max           80.000000  ...                      80.000000
#
#        bath info computed total baths  \
# count                      396.000000
# mean                         3.400253
# std                          4.096096
# min                          1.000000
# 25%                          2.000000
# 50%                          3.000000
# 75%                          3.500000
# max                         80.000000
#
#        address info centroid centroid latitude  \
# count                               399.000000
# mean                                 33.664010
# std                                   0.032359
# min                                  33.600363
# 25%                                  33.638818
# 50%                                  33.659116
# 75%                                  33.683373
# max                                  33.736599
#
#        address info centroid centroid longitude  \
# count                                399.000000
# mean                                -116.271145
# std                                    0.025742
# min                                 -116.318621
# 25%                                 -116.295514
# 50%                                 -116.267968
# 75%                                 -116.251388
# max                                 -116.233736
#
#        bath info raw three quarter baths  partial baths value  \
# count                          62.000000           209.000000
# mean                            1.790323             1.114833
# std                             1.118211             0.434365
# min                             1.000000             1.000000
# 25%                             1.000000             1.000000
# 50%                             1.000000             1.000000
# 75%                             2.000000             1.000000
# max                             5.000000             4.000000
#
#        bath info raw half baths  bath info computed partial baths  \
# count                190.000000                        209.000000
# mean                   1.078947                          1.114833
# std                    0.369583                          0.434365
# min                    1.000000                          1.000000
# 25%                    1.000000                          1.000000
# 50%                    1.000000                          1.000000
# 75%                    1.000000                          1.000000
# max                    4.000000                          4.000000
#
#        bath info raw quarter baths  last sale data last sold date nanos
# count                    24.000000                                  1.0
# mean                      1.125000                          743000000.0
# std                       0.612372                                  NaN
# min                       1.000000                          743000000.0
# 25%                       1.000000                          743000000.0
# 50%                       1.000000                          743000000.0
# 75%                       1.000000                          743000000.0
# max                       4.000000                          743000000.0
#
# [8 rows x 21 columns]
